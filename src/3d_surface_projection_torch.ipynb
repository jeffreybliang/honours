# %% [markdown]
# # Surface Projection
#
# We explore the toy example of learning a surface, represented by a set of 3D points $\{(x_i, y_i, z_i) \in \mathbb{R}^3 \mid i = 1, \ldots, m\}$, such that the projection of the surface onto the nearest ellipsoid has maximum volume (area in 2D) and unit surface area (circumference in 2D). We know that the solution to such a problem is a sphere. We will now extend our 2D problem into 3D but maintain that the ellipsoid is axis-aligned and represent it by the length of each axis $a$, $b$, and $c$. Given this representation the volume of the ellipsoid is
#
# $$
# V = \frac{4}{3} \pi a b c
# $$
#
# and surface area approximated by
#
# $$
# S \approx 4 \pi \sqrt[p]{\frac{a^pb^p + a^pc^p + b^pc^p}{3}},
# $$
# where $p\approx 1.6075$ yields a relative error of at most 1.061%.
# Full details and other approximations are discussed on [Wikipedia](https://en.wikipedia.org/wiki/Ellipsoid).
#
# ## Projection onto constrained ellipsoid
#
# The nearest ellipsoid (parametrized by $(a, b, c)$), with unit surface area, to the set of points $\{(x_i, y_i, z_i)\}$ can be found in the least-squares sense,
#
# $$
# \begin{array}{ll}
#   \text{minimize (over $a, b, c$)} & \sum_{i=1}^{m} \left(\frac{x_i^2}{a^2} + \frac{y_i^2}{b^2} + \frac{z_i^2}{c^2} - 1\right)^2 \\
#   \text{subject to} & 4 \pi \sqrt[p]{\frac{(ab)^p + (ac)^p + (bc)^p}{3}} = 1
# \end{array}
# $$
#
# which can be written in standard form as
#
# $$
# \begin{array}{ll}
#   \text{minimize} & \|A u - \mathbf{1}_m\|^2 \\
#   \text{subject to} & 4 \pi \sqrt[p]{\frac{1}{3} \left[ \left(\frac{1}{\sqrt{u_1u_2}}\right)^p + \left(\frac{1}{\sqrt{u_1u_3}}\right)^p + \left(\frac{1}{\sqrt{u_2u_3}}\right)^p \right]  } = 1
# \end{array}
# $$
#
# where
#
# $$
# A = \begin{bmatrix}
#   x_1^2 & y_1^2 & z_1^2 \\
#   \vdots & \vdots & \vdots \\
#   x_m^2 & y_m^2 & z_m^2
# \end{bmatrix}
# $$
#
# and $u = \left(\frac{1}{a^2}, \frac{1}{b^2}, \frac{1}{c^2}\right)^\top$.
#
#
# ## Bilevel optimization
#
# Our overall problem can then be stated as
#
# $$
# \begin{array}{ll}
#   \text{minimize (over $\{(x_i, y_i)\}$)} & \sqrt{u_1^\star u_2^\star u_3^\star} \\
#   \text{subject to} & u^\star = \text{argmin} \; \|Au - \mathbf{1}_m\|^2 \\
#   & \hphantom{y =} \text{subject to} \; 4 \pi \sqrt[p]{\frac{1}{3} \left[ \left({\sqrt{u_1}}\right)^p + \left({\sqrt{u_2}}\right)^p + \left({\sqrt{u_3}}\right)^p \right]  } - \sqrt{u_1u_2u_3} = 0
# \end{array}
# $$
#
# where we have stated the lower-level problem in terms of $u$ rather than $(a, b)$, and therefore instead of maximizing $\frac{4}{3} \pi a b c$, we minimize $\sqrt{u_1 u_2 u_2} = \frac{1}{abc}$.

# %%
import math
import numpy as np
import scipy.optimize as opt
import torch
import torch.nn as nn
# %matplotlib ipympl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import warnings
warnings.filterwarnings('ignore')

# ellipse area and circumferencce
def ellipsoid_volume(a, b,c):
    """Returns the volume of an ellipsoid parametrized as (x/a)^2 + (y/b)^2 + (z/c)^2 = 1."""
    return 4/3 * math.pi * a * b * c

def ellipsoid_surface_area(a, b, c, p=1.6075):
    """Returns the approximate surface area of an ellipsoid."""
    a_p = a**p
    b_p = b**p
    c_p = c**p
    return 4 * math.pi * (1/3 * (a_p*b_p + a_p*c_p + b_p*c_p))**(1/p)

# ellipse plotting
def plot_ellipsoid(ax, a, b, c, **kwargs):
    """Plot an ellipse parametrized by (a, b, c)."""
    phi = torch.linspace(0, 2 * math.pi, 100)
    theta = torch.linspace(0, math.pi, 100)
    phi, theta = torch.meshgrid(phi, theta)
    x = a * torch.sin(theta) * torch.cos(phi)
    y = b * torch.sin(theta) * torch.sin(phi)
    z = c * torch.cos(theta)
    ax.plot_wireframe(x, y, z, **kwargs)
    ax.set_aspect('equal', adjustable='box')

# ellipse fitting
def fit_ellipsoid(xs, p):
    """Find ellipsoid parameters u = (1/a^2, 1/b^2, 1/c^2) that best fit the data."""
    n_batches = xs.size(0)
    results = torch.zeros(n_batches, 3, dtype=torch.double)
    for batch_number, x in enumerate(xs):
        data = x.detach().numpy()
        A = data.T ** 2
        b = np.ones(A.shape[0])
        u0 = np.linalg.lstsq(A, b)[0]
        eq_const = {'type': 'eq',
                    'fun' : lambda u: np.array([1]) if (np.any(u < 0.0)) else 
                    np.array([
                        4 * math.pi * (1/3 * (math.sqrt(u[0])**p + math.sqrt(u[1])**p + math.sqrt(u[2])**p))**(1/p) - math.sqrt(u[0] * u[1] * u[2])
                        ])
                    }
        res = opt.minimize(lambda u: np.sum((A @ u - b) ** 2), u0, method='SLSQP', constraints=[eq_const], 
                        options={'ftol': 1e-9, 'disp': False})
        results[batch_number] = torch.tensor(res.x, dtype=torch.double, requires_grad=True)
    return results

# sample a noisy ellipse
sqrt_m = 25
m = sqrt_m * sqrt_m
a, b, c = 0.25, 0.1, 0.4
nu = 1.0e-2
p = 1.6075

print("Ellipsoid (blue) ({:0.3}, {:0.3}, {:0.3}) has volume {:0.3} and surface area {:0.3}.".format(a, b, c, ellipsoid_volume(a, b, c), ellipsoid_surface_area(a, b, c, p)))

phi = 2.0 * math.pi * torch.linspace(0.0, 1.0, sqrt_m)
theta = math.pi * torch.linspace(0.0, 1.0, sqrt_m)
phi, theta = torch.meshgrid(phi, theta)
x = a * torch.sin(theta) * torch.cos(phi)
y = b * torch.sin(theta) * torch.sin(phi)
z = c * torch.cos(theta)
data = torch.stack((x.flatten(),y.flatten(),z.flatten()), dim=0)
data = data + nu * torch.randn(3, m, dtype=torch.double)
data = data.unsqueeze(0)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
kwargs = {
    'color': 'blue',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a, b, c, **kwargs)
ax.scatter(data[0, 0].numpy(), data[0, 1].numpy(), data[0, 2].numpy(), color='b', alpha=0.8, s=1)

u = fit_ellipsoid(data, p).squeeze()
print(u[:3])
a_hat = math.sqrt(1.0 / u[0])
b_hat = math.sqrt(1.0 / u[1])
c_hat = math.sqrt(1.0 / u[2])
kwargs = {
    'color': 'red',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a_hat, b_hat, c_hat, **kwargs)

print("Ellipsoid (red) estimate ({:0.3}, {:0.3}, {:0.3}) has volume {:0.3} and surface area {:0.3}.".format(a_hat, b_hat, c_hat, ellipsoid_volume(a_hat, b_hat, c_hat), ellipsoid_surface_area(a_hat, b_hat, c_hat, p)))
plt.show()
# Out:
# Ellipsoid (blue) (0.25, 0.1, 0.4) has volume 0.0419 and surface area 0.76.
# tensor([  8.8607, 101.0578,   5.9619], dtype=torch.float64,
#        grad_fn=<SliceBackward0>)
# Ellipsoid (red) estimate (0.336, 0.0995, 0.41) has volume 0.0573 and surface area 1.0.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Derivatives
#
# Computing gradients by hand is tedious so we'll rely on autograd. Here we make use of the infrastructure provided in `ddn.basic.node` from the DDN respoitory (https://github.com/anucvml/ddn). **Requires `ddn` to be installed.**

# %%
# set correct location for DDN repository code and import basic node functionality
import sys
sys.path.append("../../../ddn/")
from ddn.pytorch.node import *
    
class EllipsoidConstrainedProjectionNode(EqConstDeclarativeNode):
    """A DDN node for the constrained ellipse projection problem. Gradients will be calculated automatically."""

    def __init__(self, m):
        super().__init__(eps=1.0e-4) # relax tolerance on optimality test 
        # make sure node is properly constructed
        self.n = tuple([3 * m]) # number of parameters x number of points
        self.m = m # number of points

    def objective(self, xs, y):
        n_batches = xs.size(0)
        data = xs.view(n_batches, 3, -1)  # reshape to (n_batches, 3, m)
        A = torch.transpose(data, 1, 2).pow(2)  # A has shape [n_batches, m, 3]
        b_tensor = torch.ones(n_batches, A.size(1), 1, device=xs.device, dtype=torch.double)  # [n_batches, m, 1]
        y = y.view(n_batches,3,1)
        return torch.sum((torch.matmul(A, y) - b_tensor).pow(2), dim=(1, 2))
    
    def equality_constraints(self, xs, y):
        # y is of shape [m x number of parameters] (same as u)
        sqrt_y = torch.sqrt(y)
        u1 = sqrt_y[:,0]
        u2 = sqrt_y[:,1]
        u3 = sqrt_y[:,2]
        average = 1/3 * (u1**p + u2**p + u3**p)
        return 4 * math.pi * average**(1/p) - u1*u2*u3
    
    def solve(self, xs):
        # process batches independently
        n_batches = xs.size(0)
        results = torch.zeros(n_batches, 3, dtype=torch.double)
        for batch_number, x in enumerate(xs):
            assert(len(x) == self.n[0])
            data = x.reshape(3, -1).detach().numpy()
            A = data.T ** 2
            b = np.ones(A.shape[0])

            # compute unconstrained solution as an initialization
            u0 = np.linalg.lstsq(A, b)[0]
            
            # now enforce constraints
            eq_const = {'type': 'eq',
                        'fun' : lambda u: np.array([1]) if (np.any(u < 0.0)) else 
                        np.array([
                            4 * math.pi * (1/3 * (math.sqrt(u[0])**p + math.sqrt(u[1])**p + math.sqrt(u[2])**p))**(1/p) - math.sqrt(u[0] * u[1] * u[2])
                            ])
                        }
            res = opt.minimize(lambda u: np.sum((A @ u - b) ** 2), u0, method='SLSQP', constraints=[eq_const], 
                            options={'ftol': 1e-9, 'disp': False})
            
            results[batch_number] = torch.tensor(res.x, dtype=torch.double, requires_grad=True)
        return results, None
    
    
class EllipsoidInverseVolumeNode(AbstractNode):
    """DDN node for computing one over the volume of an ellipsoid."""
    def __init__(self):
        super().__init__()
        self.n = m

    def solve(self, xs):
        # xs is the u vector we receive
        return torch.sqrt(xs[:,0] * xs[:,1] * xs[:,2]), None

    def gradient(self, xs, y=None, ctx=None):
        sqrt_xs = torch.sqrt(xs)
        sqrt_u1u2 = sqrt_xs[:,0] * sqrt_xs[:,1]
        sqrt_u1u3 = sqrt_xs[:,0] * sqrt_xs[:,2]
        sqrt_u2u3 = sqrt_xs[:,1] * sqrt_xs[:,2]
        gradients = 1/2 * torch.stack((sqrt_u2u3/sqrt_xs[:,0], 
                                       sqrt_u1u3/sqrt_xs[:,1],
                                       sqrt_u1u2/sqrt_xs[:,2]), dim=1)
        return tuple(gradients)
    

class ComposedNode(AbstractNode):
    """Composes two deep declarative nodes f and g to produce y = g(f(x)). The resulting composition
    behaves exactly like a single deep declarative node, that is, it has the same interface and
    as such can be further composed with other nodes to form a chain."""

    def __init__(self, nodeA, nodeB):
        assert (nodeA.m == nodeB.n)
        super().__init__()
        self.nodeA = nodeA
        self.nodeB = nodeB

    def solve(self, x):
        """Overrides the solve method to first compute z = nodeA.solve(x) and then y = nodeB.solve(z). Returns
        the dual variables from both nodes."""
        z, ctxA = self.nodeA.solve(x)
        y, ctxB = self.nodeB.solve(z)
        return y, {'ctxA': ctxA, 'ctxB': ctxB, 'z': z}

    def gradient(self, x, y=None, ctx=None):
        """Overrides the gradient method to compute the composed gradient by the chain rule."""

        # we need to resolve for z since there is currently no way to store this
        if ctx is None:
            z, _ = self.nodeA.solve(x)
        else:
            z = ctx['z']
        Dz = self.nodeA.jacobian(x, y=z)
        Dz = torch.stack(Dz).squeeze(0)
        # print("Dz.shape, Dz", Dz.shape, Dz, "type", type(Dz), "len", len(Dz))
        Dy = self.nodeB.gradient(z)
        Dy = torch.stack(Dy)
        Dy = Dy.view(Dy.size(0),1,-1)
        # print("Dy.shape, Dy", Dy.shape, Dy, "type", type(Dy), "len", len(Dy))
        # print("result", torch.bmm(Dy, Dz))
        return torch.bmm(Dy, Dz)

# %% [markdown]
# # Optimizing
#
# We now optimize the inital samples in a direction to maximize the area of the projected ellipse using gradient descent.

# %%
from ddn.pytorch.composition import ComposedNode

node = ComposedNode(EllipsoidConstrainedProjectionNode(m), EllipsoidInverseVolumeNode())

n_batches = data.size(0)
x_init = data.view(n_batches, -1)
x_init.requires_grad = True
y_init, _ = node.solve(x_init)

history = [y_init]

x = x_init.clone()
for i in range(50):
    y, _ = node.solve(x)

    history.append(y)

    if True:
        u = fit_ellipsoid(x.view(n_batches, 3, -1), p)
        a_hat = math.sqrt(1.0 / u[:,0])
        b_hat = math.sqrt(1.0 / u[:,1])
        c_hat = math.sqrt(1.0 / u[:,2])
        print("{:5d}: ellipsoid estimate ({:0.3}, {:0.3}, {:0.3}) has volume {:0.3} and surface area {:0.3}.".format(i, a_hat, b_hat, c_hat, ellipsoid_volume(a_hat, b_hat, c_hat), ellipsoid_surface_area(a_hat, b_hat, c_hat, p)))
    ctx = {'z': u}
    dLdx = node.gradient(x, y, ctx=ctx)
    x -= 4.0e-2 * dLdx.flatten()
    
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
kwargs = {
    'color': 'blue',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a, b, c, **kwargs)
ax.scatter(data[0, 0].numpy(), data[0, 1].numpy(), data[0, 2].numpy(), color='b', alpha=0.8, s=1)


final_data = x.reshape(1, 3, -1).detach()
ax.scatter(final_data[0, 0].numpy(), final_data[0, 1].numpy(), final_data[0, 2].numpy(), color='g', marker='+', alpha=0.8, s=1)

u = fit_ellipsoid(final_data, p)
a_hat = math.sqrt(1.0 / u[:,0])
b_hat = math.sqrt(1.0 / u[:,1])
c_hat = math.sqrt(1.0 / u[:,2])
kwargs = {
    'color': 'green',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a_hat, b_hat, c_hat, **kwargs)

print("Final ellipsoid ({:0.3}, {:0.3},{:0.3}) has volume {:0.3} and surface area {:0.3}.".format(a_hat, b_hat, c_hat, ellipsoid_volume(a_hat, b_hat, c_hat), ellipsoid_surface_area(a_hat, b_hat, c_hat, p)))
# plt.axis('square')
plt.legend(['initial true', 'initial samples', 'final samples', 'final projected'])
plt.show()
# Out:
#     0: ellipsoid estimate (0.335, 0.1, 0.41) has volume 0.0576 and surface area 1.0.
#     1: ellipsoid estimate (0.2, 0.315, 0.333) has volume 0.088 and surface area 1.0.
#     2: ellipsoid estimate (0.21, 0.308, 0.33) has volume 0.0894 and surface area 1.0.
#     3: ellipsoid estimate (0.218, 0.303, 0.327) has volume 0.0904 and surface area 1.0.
#     4: ellipsoid estimate (0.224, 0.298, 0.325) has volume 0.0911 and surface area 1.0.
#     5: ellipsoid estimate (0.23, 0.295, 0.323) has volume 0.0917 and surface area 1.0.
#     6: ellipsoid estimate (0.235, 0.291, 0.321) has volume 0.0921 and surface area 1.0.
#     7: ellipsoid estimate (0.239, 0.289, 0.319) has volume 0.0924 and surface area 1.0.
#     8: ellipsoid estimate (0.243, 0.287, 0.317) has volume 0.0927 and surface area 1.0.
#     9: ellipsoid estimate (0.247, 0.285, 0.315) has volume 0.0929 and surface area 1.0.
#    10: ellipsoid estimate (0.25, 0.284, 0.314) has volume 0.093 and surface area 1.0.
#    11: ellipsoid estimate (0.252, 0.282, 0.312) has volume 0.0932 and surface area 1.0.
#    12: ellipsoid estimate (0.255, 0.281, 0.311) has volume 0.0933 and surface area 1.0.
#    13: ellipsoid estimate (0.257, 0.281, 0.309) has volume 0.0934 and surface area 1.0.
#    14: ellipsoid estimate (0.259, 0.28, 0.308) has volume 0.0935 and surface area 1.0.
#    15: ellipsoid estimate (0.261, 0.279, 0.306) has volume 0.0935 and surface area 1.0.
#    16: ellipsoid estimate (0.263, 0.279, 0.305) has volume 0.0936 and surface area 1.0.
#    17: ellipsoid estimate (0.264, 0.279, 0.304) has volume 0.0937 and surface area 1.0.
#    18: ellipsoid estimate (0.265, 0.278, 0.303) has volume 0.0937 and surface area 1.0.
#    19: ellipsoid estimate (0.267, 0.278, 0.302) has volume 0.0937 and surface area 1.0.
#    20: ellipsoid estimate (0.268, 0.278, 0.301) has volume 0.0938 and surface area 1.0.
#    21: ellipsoid estimate (0.269, 0.278, 0.3) has volume 0.0938 and surface area 1.0.
#    22: ellipsoid estimate (0.27, 0.278, 0.299) has volume 0.0938 and surface area 1.0.
#    23: ellipsoid estimate (0.27, 0.278, 0.298) has volume 0.0938 and surface area 1.0.
#    24: ellipsoid estimate (0.271, 0.278, 0.297) has volume 0.0939 and surface area 1.0.
#    25: ellipsoid estimate (0.272, 0.278, 0.296) has volume 0.0939 and surface area 1.0.
#    26: ellipsoid estimate (0.273, 0.278, 0.295) has volume 0.0939 and surface area 1.0.
#    27: ellipsoid estimate (0.273, 0.278, 0.295) has volume 0.0939 and surface area 1.0.
#    28: ellipsoid estimate (0.274, 0.279, 0.294) has volume 0.0939 and surface area 1.0.
#    29: ellipsoid estimate (0.274, 0.279, 0.293) has volume 0.0939 and surface area 1.0.
#    30: ellipsoid estimate (0.275, 0.279, 0.293) has volume 0.094 and surface area 1.0.
#    31: ellipsoid estimate (0.275, 0.279, 0.292) has volume 0.094 and surface area 1.0.
#    32: ellipsoid estimate (0.276, 0.279, 0.291) has volume 0.094 and surface area 1.0.
#    33: ellipsoid estimate (0.276, 0.279, 0.291) has volume 0.094 and surface area 1.0.
#    34: ellipsoid estimate (0.277, 0.279, 0.29) has volume 0.094 and surface area 1.0.
#    35: ellipsoid estimate (0.277, 0.279, 0.29) has volume 0.094 and surface area 1.0.
#    36: ellipsoid estimate (0.277, 0.28, 0.289) has volume 0.094 and surface area 1.0.
#    37: ellipsoid estimate (0.278, 0.28, 0.289) has volume 0.094 and surface area 1.0.
#    38: ellipsoid estimate (0.278, 0.28, 0.289) has volume 0.094 and surface area 1.0.
#    39: ellipsoid estimate (0.278, 0.28, 0.288) has volume 0.094 and surface area 1.0.
#    40: ellipsoid estimate (0.278, 0.28, 0.288) has volume 0.094 and surface area 1.0.
#    41: ellipsoid estimate (0.279, 0.28, 0.288) has volume 0.094 and surface area 1.0.
#    42: ellipsoid estimate (0.279, 0.28, 0.287) has volume 0.094 and surface area 1.0.
#    43: ellipsoid estimate (0.279, 0.28, 0.287) has volume 0.094 and surface area 1.0.
#    44: ellipsoid estimate (0.279, 0.28, 0.287) has volume 0.094 and surface area 1.0.
#    45: ellipsoid estimate (0.279, 0.281, 0.286) has volume 0.094 and surface area 1.0.
#    46: ellipsoid estimate (0.279, 0.281, 0.286) has volume 0.094 and surface area 1.0.
#    47: ellipsoid estimate (0.28, 0.281, 0.286) has volume 0.094 and surface area 1.0.
#    48: ellipsoid estimate (0.28, 0.281, 0.286) has volume 0.094 and surface area 1.0.
#    49: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.094 and surface area 1.0.
# Final ellipsoid (0.28, 0.281,0.285) has volume 0.094 and surface area 1.0.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
node = EllipsoidConstrainedProjectionNode(m)

class EllipseConstrainedProjectionFunction(DeclarativeFunction):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

class SqrtProductLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, input):
        return torch.sqrt(input[:,0] * input[:,1] * input[:,2])

y_init = EllipseConstrainedProjectionFunction.apply(node, x_init)
sqrt_prod_loss = SqrtProductLoss()
history = [y_init]
x = x_init.clone().detach().requires_grad_(True)
torch_opt = torch.optim.SGD([x], lr=0.05)
# lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=torch_opt,
#                                                           mode='min',
#                                                           factor=0.8,
#                                                           patience=3,
#                                                           threshold=1e-4)

for i in range(60):
    torch_opt.zero_grad(set_to_none=True)
    y = EllipseConstrainedProjectionFunction.apply(node, x)
    history.append(y.detach().clone())
    if True:
        u = fit_ellipsoid(x.view(n_batches, 3, -1), p)
        a_hat = math.sqrt(1.0 / u[:,0])
        b_hat = math.sqrt(1.0 / u[:,1])
        c_hat = math.sqrt(1.0 / u[:,2])
        print("{:5d}: ellipsoid estimate ({:0.3}, {:0.3}, {:0.3}) has volume {:0.7} and surface area {:0.3}.".format(i, a_hat, b_hat, c_hat, ellipsoid_volume(a_hat, b_hat, c_hat), ellipsoid_surface_area(a_hat, b_hat, c_hat, p)))
    loss = sqrt_prod_loss(y)
    loss.backward()
    torch_opt.step()

    # lr_scheduler.step(loss)
    # current_lr = torch_opt.param_groups[0]['lr']
    # print(f"Iteration {i}: Current Learning Rate = {current_lr:.6f}")


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
kwargs = {
    'color': 'blue',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a, b, c, **kwargs)
ax.scatter(data[0, 0].numpy(), data[0, 1].numpy(), data[0, 2].numpy(), color='b', alpha=0.8, s=1)

final_data = x.reshape(1, 3, -1).detach()
ax.scatter(final_data[0, 0].numpy(), final_data[0, 1].numpy(), final_data[0, 2].numpy(), color='g', marker='+', alpha=0.8, s=1)

u = fit_ellipsoid(final_data, p)
a_hat = math.sqrt(1.0 / u[:,0])
b_hat = math.sqrt(1.0 / u[:,1])
c_hat = math.sqrt(1.0 / u[:,2])
kwargs = {
    'color': 'green',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a_hat, b_hat, c_hat, **kwargs)

print("Final ellipsoid ({:0.3}, {:0.3},{:0.3}) has volume {:0.7} and surface area {:0.3}.".format(a_hat, b_hat, c_hat, ellipsoid_volume(a_hat, b_hat, c_hat), ellipsoid_surface_area(a_hat, b_hat, c_hat, p)))
# plt.axis('square')
plt.legend(['initial true', 'initial samples', 'final samples', 'final projected'])
plt.show()
# Out:
#     0: ellipsoid estimate (0.335, 0.1, 0.41) has volume 0.05763789 and surface area 1.0.
#     1: ellipsoid estimate (0.192, 0.34, 0.316) has volume 0.08662642 and surface area 1.0.
#     2: ellipsoid estimate (0.204, 0.331, 0.313) has volume 0.08855422 and surface area 1.0.
#     3: ellipsoid estimate (0.213, 0.324, 0.311) has volume 0.08988049 and surface area 1.0.
#     4: ellipsoid estimate (0.221, 0.317, 0.309) has volume 0.09083443 and surface area 1.0.
#     5: ellipsoid estimate (0.228, 0.312, 0.308) has volume 0.09153982 and surface area 1.0.
#     6: ellipsoid estimate (0.233, 0.308, 0.306) has volume 0.09207132 and surface area 1.0.
#     7: ellipsoid estimate (0.238, 0.304, 0.305) has volume 0.09247729 and surface area 1.0.
#     8: ellipsoid estimate (0.243, 0.3, 0.304) has volume 0.09279064 and surface area 1.0.
#     9: ellipsoid estimate (0.247, 0.297, 0.303) has volume 0.09303453 and surface area 1.0.
#    10: ellipsoid estimate (0.25, 0.295, 0.302) has volume 0.09322573 and surface area 1.0.
#    11: ellipsoid estimate (0.253, 0.293, 0.301) has volume 0.09337656 and surface area 1.0.
#    12: ellipsoid estimate (0.256, 0.291, 0.299) has volume 0.09349625 and surface area 1.0.
#    13: ellipsoid estimate (0.259, 0.289, 0.299) has volume 0.09359174 and surface area 1.0.
#    14: ellipsoid estimate (0.261, 0.288, 0.298) has volume 0.09366834 and surface area 1.0.
#    15: ellipsoid estimate (0.263, 0.287, 0.297) has volume 0.09373011 and surface area 1.0.
#    16: ellipsoid estimate (0.265, 0.286, 0.296) has volume 0.09378017 and surface area 1.0.
#    17: ellipsoid estimate (0.266, 0.285, 0.295) has volume 0.09382095 and surface area 1.0.
#    18: ellipsoid estimate (0.268, 0.284, 0.294) has volume 0.09385435 and surface area 1.0.
#    19: ellipsoid estimate (0.269, 0.284, 0.294) has volume 0.09388184 and surface area 1.0.
#    20: ellipsoid estimate (0.27, 0.283, 0.293) has volume 0.09390458 and surface area 1.0.
#    21: ellipsoid estimate (0.271, 0.283, 0.292) has volume 0.09392347 and surface area 1.0.
#    22: ellipsoid estimate (0.272, 0.282, 0.292) has volume 0.09393926 and surface area 1.0.
#    23: ellipsoid estimate (0.273, 0.282, 0.291) has volume 0.0939525 and surface area 1.0.
#    24: ellipsoid estimate (0.274, 0.282, 0.291) has volume 0.09396365 and surface area 1.0.
#    25: ellipsoid estimate (0.274, 0.282, 0.29) has volume 0.09397309 and surface area 1.0.
#    26: ellipsoid estimate (0.275, 0.282, 0.29) has volume 0.0939811 and surface area 1.0.
#    27: ellipsoid estimate (0.276, 0.281, 0.289) has volume 0.09398793 and surface area 1.0.
#    28: ellipsoid estimate (0.276, 0.281, 0.289) has volume 0.09399376 and surface area 1.0.
#    29: ellipsoid estimate (0.277, 0.281, 0.288) has volume 0.09399877 and surface area 1.0.
#    30: ellipsoid estimate (0.277, 0.281, 0.288) has volume 0.09400307 and surface area 1.0.
#    31: ellipsoid estimate (0.278, 0.281, 0.288) has volume 0.09400678 and surface area 1.0.
#    32: ellipsoid estimate (0.278, 0.281, 0.287) has volume 0.09400999 and surface area 1.0.
#    33: ellipsoid estimate (0.278, 0.281, 0.287) has volume 0.09401276 and surface area 1.0.
#    34: ellipsoid estimate (0.279, 0.281, 0.287) has volume 0.09401516 and surface area 1.0.
#    35: ellipsoid estimate (0.279, 0.281, 0.286) has volume 0.09401725 and surface area 1.0.
#    36: ellipsoid estimate (0.279, 0.281, 0.286) has volume 0.09401907 and surface area 1.0.
#    37: ellipsoid estimate (0.279, 0.281, 0.286) has volume 0.09402064 and surface area 1.0.
#    38: ellipsoid estimate (0.28, 0.281, 0.286) has volume 0.09402202 and surface area 1.0.
#    39: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402322 and surface area 1.0.
#    40: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402427 and surface area 1.0.
#    41: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402518 and surface area 1.0.
#    42: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402598 and surface area 1.0.
#    43: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402668 and surface area 1.0.
#    44: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402729 and surface area 1.0.
#    45: ellipsoid estimate (0.281, 0.281, 0.284) has volume 0.09402783 and surface area 1.0.
#    46: ellipsoid estimate (0.281, 0.281, 0.284) has volume 0.0940283 and surface area 1.0.
#    47: ellipsoid estimate (0.281, 0.281, 0.284) has volume 0.0940287 and surface area 1.0.
#    48: ellipsoid estimate (0.281, 0.281, 0.284) has volume 0.09402906 and surface area 1.0.
#    49: ellipsoid estimate (0.281, 0.281, 0.284) has volume 0.09402938 and surface area 1.0.
#    50: ellipsoid estimate (0.281, 0.282, 0.284) has volume 0.09402965 and surface area 1.0.
#    51: ellipsoid estimate (0.281, 0.282, 0.284) has volume 0.09402989 and surface area 1.0.
#    52: ellipsoid estimate (0.281, 0.282, 0.284) has volume 0.0940301 and surface area 1.0.
#    53: ellipsoid estimate (0.281, 0.282, 0.283) has volume 0.09403029 and surface area 1.0.
#    54: ellipsoid estimate (0.281, 0.282, 0.283) has volume 0.09403045 and surface area 1.0.
#    55: ellipsoid estimate (0.281, 0.282, 0.283) has volume 0.09403059 and surface area 1.0.
#    56: ellipsoid estimate (0.281, 0.282, 0.283) has volume 0.09403072 and surface area 1.0.
#    57: ellipsoid estimate (0.281, 0.282, 0.283) has volume 0.09403083 and surface area 1.0.
#    58: ellipsoid estimate (0.282, 0.282, 0.283) has volume 0.09403092 and surface area 1.0.
#    59: ellipsoid estimate (0.282, 0.282, 0.283) has volume 0.09403101 and surface area 1.0.
# Final ellipsoid (0.282, 0.282,0.283) has volume 0.09403108 and surface area 1.0.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
r = math.sqrt(1/(4*math.pi))
condition = (final_data[0, 0]**2 + final_data[0, 1]**2 + final_data[0, 2]**2) < (r**2)

# Reshape the condition to match the tensor shape for indexing
mask = condition.unsqueeze(0).expand_as(final_data)

# Use the mask to index the tensor
filtered_data = final_data[mask].view(final_data.size(0), final_data.size(1), -1)

print(f"There are {len(filtered_data[0][0])} points inside the ellipsoid.")

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
kwargs = {
    'color': 'blue',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.1
}
plot_ellipsoid(ax, a_hat, b_hat, c_hat, **kwargs)
ax.scatter(filtered_data[0, 0].numpy(), filtered_data[0, 1].numpy(), filtered_data[0, 2].numpy(), color='g', marker='+', alpha=0.8, s=1)
plt.show()
# Out:
# There are 28 points inside the ellipsoid
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Projection onto constrained non-axis-aligned ellipsoid
#
# The nearest non-axis-aligned ellipsoid (parametrized by $(a, b, c, \theta, \phi, \psi)$), with unit surface area, to the set of points $\{\mathbf x_i\}$ can be found in the least-squares sense,
#
# $$
# \begin{array}{ll}
#   \text{minimize (over $A_{ij}$)} & \sum_{i=1}^{m} \left({\mathbf x_i}^\top \mathbf A \mathbf x_i - 1\right)^2 \\
#   \text{subject to} & 4 \pi \sqrt[p]{\frac{(ab)^p + (ac)^p + (bc)^p}{3}} = 1
# \end{array}
# $$
#
# which can be written in standard form as
#
# $$
# \begin{array}{ll}
#   \text{minimize} & \| \text{diag}(X^\top AX) - \mathbf{1}_m\|^2 \\
#   \text{subject to} & 4 \pi \sqrt[p]{\frac{1}{3} \left[ \left(\frac{1}{\sqrt{u_1u_2}}\right)^p + \left(\frac{1}{\sqrt{u_1u_3}}\right)^p + \left(\frac{1}{\sqrt{u_2u_3}}\right)^p \right]  } = 1
# \end{array}
# $$
#
# where
#
# $$
# X = \begin{bmatrix}
#   | & \cdots & | \\
#   \mathbf x_1 & \cdots & \mathbf x_m \\
#   | & \cdots & |
# \end{bmatrix}
# $$
#
# and $u = \left(\frac{1}{a^2}, \frac{1}{b^2}, \frac{1}{c^2}\right)^\top = \left(\lambda_1, \lambda_2, \lambda_3\right)^\top$.
#
#
# <!-- Note that if $A$ can be decomposed by an eigendecomposition into $A = U^T \Lambda U$ where $U$ is an orthonormal rotation matrix and $\Lambda$ is a diagonal matrix of eigenvalues, then it is valid. -->
#
#
# ## Bilevel optimization
#
# Our overall problem can then be stated as
#
# $$
# \begin{array}{ll}
#   \text{minimize (over $\{(x_i, y_i)\}$)} & \sqrt{u_1^\star u_2^\star u_3^\star} \\
#   \text{subject to} & u^\star = \text{argmin} \; \| \text{diag}(X^\top AX) - \mathbf{1}_m\|^2 \\
#   & \hphantom{y =} \text{subject to} \; 4 \pi \sqrt[p]{\frac{1}{3} \left[ \left({\sqrt{u_1}}\right)^p + \left({\sqrt{u_2}}\right)^p + \left({\sqrt{u_3}}\right)^p \right]  } - \sqrt{u_1u_2u_3} = 0
# \end{array}
# $$
#
# where we have stated the lower-level problem in terms of $u$ rather than $(a, b)$, and therefore instead of maximizing $\frac{4}{3} \pi a b c$, we minimize $\sqrt{u_1 u_2 u_2} = \frac{1}{abc}$.

# %%
from math import cos, sin, radians

def rotation_matrix_3d(yaw, pitch, roll):
    yaw, pitch, roll = radians(yaw), radians(pitch), radians(roll)
    alpha, beta, gamma = yaw, pitch, roll
    R_z = torch.tensor([[cos(yaw), -sin(yaw), 0],
                        [sin(yaw), cos(yaw) , 0],
                        [0             , 0              , 1]])
    R_y = torch.tensor([[cos(pitch), 0, sin(pitch)],
                        [0, 1, 0],
                        [-sin(pitch), 0, cos(pitch)]])
    R_x = torch.tensor([[1, 0, 0],
                        [0, cos(roll), -sin(roll)],
                        [0, sin(roll), cos(roll)]])
    R = torch.tensor([
        [cos(alpha)*cos(beta), cos(alpha)*sin(beta)*sin(gamma)-sin(alpha)*cos(gamma), cos(alpha)*sin(beta)*cos(gamma)+sin(alpha)*sin(gamma)],
        [sin(alpha)*cos(beta), sin(alpha)*sin(beta)*sin(gamma)+cos(alpha)*cos(gamma), sin(alpha)*sin(beta)*cos(gamma)-cos(alpha)*sin(gamma)],
        [-sin(beta), cos(beta)*sin(gamma), cos(beta)*cos(gamma)]
    ])

    return R_x, R_y, R_z, R

# %%
# ellipse area and circumferencce
def ellipsoid_volume(a, b,c):
    """Returns the volume of an ellipsoid parametrized as (x/a)^2 + (y/b)^2 + (z/c)^2 = 1."""
    return 4/3 * math.pi * a * b * c

def ellipsoid_surface_area(a, b, c, p=1.6075):
    """Returns the approximate surface area of an ellipsoid."""
    a_p = a**p
    b_p = b**p
    c_p = c**p
    return 4 * math.pi * (1/3 * (a_p*b_p + a_p*c_p + b_p*c_p))**(1/p)

def constraint_function(A):
    # Calculate surface area from matrix
    A = A.reshape(3,3)
    u, _ = np.linalg.eigh(A)
    if np.any(u < 0.0):
        return np.array([5])
    else:
        return np.array([4 * math.pi * (1/3 * (math.sqrt(u[0])**p + math.sqrt(u[1])**p + math.sqrt(u[2])**p))**(1/p) - math.sqrt(u[0] * u[1] * u[2])])

def objective_function(A, X):
    A = A.reshape(3,3)
    XT_AX = np.einsum('ji,jk,ki->i', X, A, X)
    b = np.ones(X.shape[1])
    print(np.sum((XT_AX - b) ** 2))
    return np.sum((XT_AX - b) ** 2)

# ellipse fitting
def fit_ellipsoid(xs, p):
    """Find ellipsoid parameters u = (1/a^2, 1/b^2, 1/c^2) that best fit the data."""
    n_batches = xs.size(0)
    results = torch.zeros(n_batches, 9, dtype=torch.double)
    for batch_number, x in enumerate(xs):
        X = x.detach().numpy()
        # u0 = np.identity(3).flatten()
        u0 = np.array([ 16.2633917 , -20.70814283, -10.12596782, -20.70814283,
        89.37827016,  18.75535716, -10.12596782,  18.75535716,
        16.60833304]) # better initial guess
        eq_const = {'type': 'eq',
                    'fun' : lambda A: constraint_function(A)
                    }
        res = opt.minimize(lambda A: objective_function(A, X), u0, method='SLSQP', constraints=[eq_const], 
                        options={'ftol': 1e-6, 'eps': 4e-3,'disp': False})
        results[batch_number] = torch.tensor(res.x, dtype=torch.double, requires_grad=True)
    return results

def plot_ellipsoid(ax, a, b, c, yaw, pitch, roll, **kwargs):
    phi = 2.0 * math.pi * torch.linspace(0.0, 1.0, sqrt_m)
    theta = math.pi * torch.linspace(0.0, 1.0, sqrt_m)
    phi, theta = torch.meshgrid(phi, theta)
    x = a * torch.sin(theta) * torch.cos(phi)
    y = b * torch.sin(theta) * torch.sin(phi)
    z = c * torch.cos(theta)
    # Flatten the arrays
    x_flat = x.flatten()
    y_flat = y.flatten()
    z_flat = z.flatten()

    # Stack the coordinates
    coords = torch.stack((x_flat, y_flat, z_flat), dim=1)
    _,_,_,rotation_matrix = rotation_matrix_3d(yaw, pitch, roll)
    # Apply rotation if rotation_matrix is given
    coords = coords @ rotation_matrix.T
    # Reshape the rotated coordinates back to the original shape
    x_rot = coords[:, 0].reshape(x.shape)
    y_rot = coords[:, 1].reshape(y.shape)
    z_rot = coords[:, 2].reshape(z.shape)

    ax.plot_wireframe(x_rot.numpy(), y_rot.numpy(), z_rot.numpy(), **kwargs)
    ax.set_aspect('equal', adjustable='box')

def generate_data(sqrt_m, m, a, b, c, yaw, pitch, roll, nu, p):
    phi = 2.0 * math.pi * torch.linspace(0.0, 1.0, sqrt_m)
    theta = math.pi * torch.linspace(0.0, 1.0, sqrt_m)
    phi, theta = torch.meshgrid(phi, theta)
    x = a * torch.sin(theta) * torch.cos(phi)
    y = b * torch.sin(theta) * torch.sin(phi)
    z = c * torch.cos(theta)
    # Flatten the arrays
    x_flat = x.flatten()
    y_flat = y.flatten()
    z_flat = z.flatten()
    coords = torch.stack((x_flat, y_flat, z_flat), dim=0)
    _,_,_,rotation_matrix = rotation_matrix_3d(yaw, pitch, roll)
    coords = rotation_matrix @ coords
    data = coords + nu * torch.randn(3, m, dtype=torch.double)
    data = data.unsqueeze(0)
    return data

def extract_params(A):
    eigvals, Q = torch.linalg.eigh(A)
    a, b, c = eigvals
    pitch = -math.asin(Q[2,0])
    denom = math.sqrt(1 - Q[2,0]*Q[2,0])
    roll = math.atan2(Q[2,1]/denom, Q[2,2]/denom)
    yaw = math.atan2(Q[1,0]/denom, Q[0,0]/denom)
    return a,b,c,yaw,pitch,roll

# sample a noisy ellipse
sqrt_m = 25
m = sqrt_m * sqrt_m
a, b, c = 0.25, 0.1, 0.4
yaw, pitch, roll = 30.0, 45., 20.
nu = 1.0e-4
p = 1.6075


print(f"Ellipsoid (blue) ({a:0.3}, {b:0.3}, {c:0.3}, {yaw:0.3}\N{DEGREE SIGN}, {pitch:0.3}\N{DEGREE SIGN}, {roll:0.3}\N{DEGREE SIGN}) has volume {ellipsoid_volume(a, b, c):0.3} and surface area {ellipsoid_surface_area(a, b, c, p):0.3}")

data = generate_data(sqrt_m, m, a, b, c, yaw, pitch, roll, nu, p)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
kwargs = {
    'color': 'blue',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a, b, c, yaw, pitch, roll, **kwargs)
ax.scatter(data[0, 0].numpy(), data[0, 1].numpy(), data[0, 2].numpy(), color='b', alpha=0.8, s=1)

A_flat = fit_ellipsoid(data, p).squeeze()
A = A_flat.reshape(3,3)
print(A)
a_hat, b_hat, c_hat, roll_hat, yaw_hat, pitch_hat = extract_params(A.detach())
kwargs = {
    'color': 'red',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a_hat, b_hat, c_hat, roll_hat, yaw_hat, pitch_hat, **kwargs)

print(f"Ellipsoid (red) ({a_hat:0.3}, {b_hat:0.3}, {c_hat:0.3}, {math.degrees(yaw_hat):0.3}\N{DEGREE SIGN}, {math.degrees(pitch_hat):0.3}\N{DEGREE SIGN}, {math.degrees(roll_hat):0.3}\N{DEGREE SIGN}) has volume {ellipsoid_volume(a_hat, b_hat, c_hat):0.3} and surface area {ellipsoid_surface_area(a_hat, b_hat, c_hat, p):0.3}")
plt.show()
# Out:
# Ellipsoid (blue) (0.25, 0.1, 0.4, 30.0°, 45.0°, 20.0°) has volume 0.0419 and surface area 0.76
# 0.0007237628563173626
# 0.0007739098246684769
# 0.0007305953885272031
# 0.0007525451732055678
# 0.0007305953885272023
# 0.0007258815199410871
# 0.00072909903657731
# 0.0007525451732055698
# 0.0007290990365773069
# 0.0007559103159722418
# 35.89919720909569
# 0.3590744783652618
# 0.3520212001651384
# 0.3585773721954395
# 0.3535285904122317
# 0.3585773721954399
# 0.35883819536452893
# 0.35900209823254303
# 0.35352859041223167
# 0.35900209823254314
# 0.35328568677183225
# 3.385234858143757
# 3.3664288502635813
# 3.383050755552718
# 3.3739400796262284
# 3.3830507555527176
# 3.383895566233571
# 3.3861955792359657
# 3.3739400796262284
# 3.3861955792359657
# 3.368891743311012
# 1.1891779147934658
# 1.1817194995520512
# 1.1878549333482455
# 1.1865650431575112
# 1.1878549333482455
# 1.1882877391809277
# 1.1901253713072042
# 1.1865650431575112
# 1.190125371307204
# 1.1824431763058194
# 0.31434277049195863
# 0.3136424840039355
# 0.3138390931079833
# 0.3156693013735489
# 0.3138390931079833
# 0.3139344562142734
# 0.3149669688902662
# 0.3156693013735488
# 0.3149669688902662
# 0.31326956181173915
# 0.027571651320267232
# 0.028565300391647508
# 0.02752397461753426
# 0.028859805199570005
# 0.02752397461753426
# 0.027512735998121887
# 0.027715414231458957
# 0.028859805199570016
# 0.027715414231458964
# 0.028409096390484643
# 0.0016601722700748285
# 0.002034692626148889
# 0.0016973748684118938
# 0.0019416719938848332
# 0.0016973748684118801
# 0.0016637376057783786
# 0.0016833037400267236
# 0.001941671993884844
# 0.0016833037400267215
# 0.0018831675224633589
# 0.0008966561347943851
# 0.0008837760831753964
# 0.0008950776707019235
# 0.0009099813047867663
# 0.0008950776707019178
# 0.0008940595945120123
# 0.0008877685797714779
# 0.0009099813047867708
# 0.0008877685797714719
# 0.0009474665626778404
# 0.0008542208276853467
# 0.000848328594219426
# 0.0008602720133171511
# 0.0008432912878246738
# 0.0008602720133171477
# 0.0008503187276177613
# 0.0008554386105634722
# 0.000843291287824673
# 0.0008554386105634778
# 0.0008368260337611131
# 0.0008428953257746659
# 0.0008408102443326892
# 0.000846654772449548
# 0.0008427295795316832
# 0.0008466547724495401
# 0.0008388441802972587
# 0.0008427234611057095
# 0.0008427295795316802
# 0.0008427234611057071
# 0.0008412140351935532
# 0.0008348261275838817
# 0.0008341637769139423
# 0.0008369358375659222
# 0.0008386238753231732
# 0.0008369358375659157
# 0.0008306771512259252
# 0.0008336014941820548
# 0.0008386238753231613
# 0.0008336014941820618
# 0.0008390624407371501
# 0.0008155649646873175
# 0.0008174930334886937
# 0.0008141915836023831
# 0.0008237040129689395
# 0.000814191583602365
# 0.0008112808503575018
# 0.0008121096816971797
# 0.0008237040129689403
# 0.0008121096816971825
# 0.0008260956741452622
# 0.0008000095740312503
# 0.0008030059614506427
# 0.0007967008924060749
# 0.0008069995297249988
# 0.0007967008924060825
# 0.0007957698433199549
# 0.0007954197812868801
# 0.0008069995297249994
# 0.0007954197812868741
# 0.0008086986063802122
# 0.0007824000971368303
# 0.0007854401449504074
# 0.000778209436793924
# 0.0007845827943435999
# 0.000778209436793915
# 0.0007784308428812981
# 0.0007776389805060487
# 0.0007845827943435931
# 0.0007776389805060448
# 0.0007840159318223401
# 0.0007635497706671595
# 0.0007657288753466729
# 0.0007597528889996705
# 0.0007598087488424595
# 0.0007597528889996734
# 0.0007601225963595184
# 0.0007598765326820499
# 0.0007598087488424714
# 0.0007598765326820565
# 0.0007568863320036546
# 0.0007435963789844032
# 0.0007443704401685201
# 0.0007413375793164278
# 0.0007355988100706032
# 0.0007413375793164302
# 0.0007410332871923221
# 0.0007423009113981009
# 0.0007355988100706024
# 0.0007423009113981032
# 0.0007317704739664508
# 0.0007327295501200514
# 0.0007326799592474529
# 0.0007320100304293096
# 0.000726207153536553
# 0.000732010030429312
# 0.0007309105442356962
# 0.0007335823401220976
# 0.0007262071535365593
# 0.0007335823401220983
# 0.000724265856650558
# 0.0007311338815503817
# 0.0007311757597505062
# 0.0007309082830790953
# 0.0007286793971081078
# 0.0007309082830790916
# 0.0007296288206431597
# 0.0007326120262979453
# 0.0007286793971081112
# 0.0007326120262979423
# 0.0007291463369017198
# 0.0007319232586766695
# 0.0007313030337473916
# 0.0007311842214284921
# 0.0007311505814174686
# 0.0007311396343034621
# 0.0007311358895772314
# 0.000731134585717536
# 0.0007311341288874693
# 0.0007311339684767261
# 0.0007311339121066993
# 0.0007311338922922851
# tensor([[ 16.2593, -19.5363,  -7.0510],
#         [-21.8646,  89.3491,  17.9598],
#         [-13.1940,  19.5253,  16.6037]], dtype=torch.float64,
#        grad_fn=<ViewBackward0>)
# Ellipsoid (red) (3.17, 17.7, 1.01e+02, -42.4°, 1.1e+02°, 2.66°) has volume 2.39e+04 and surface area 1.19e+04
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
_,_,_,R=rotation_matrix_3d(yaw, pitch, roll)
A_ = R.numpy() @ np.diag([1/a**2,1/b**2,1/c**2]) @ R.numpy().T
A_
# Out:
# array([[ 16.2633917 , -20.70814283, -10.12596782],
#        [-20.70814283,  89.37827016,  18.75535716],
#        [-10.12596782,  18.75535716,  16.60833304]])
