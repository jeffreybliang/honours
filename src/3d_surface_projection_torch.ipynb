# %% [markdown]
# # Surface Projection
#
# We explore the toy example of learning a surface, represented by a set of 3D points $\{(x_i, y_i, z_i) \in \mathbb{R}^3 \mid i = 1, \ldots, m\}$, such that the projection of the surface onto the nearest ellipsoid has maximum volume (area in 2D) and unit surface area (circumference in 2D). We know that the solution to such a problem is a sphere. We will now extend our 2D problem into 3D but maintain that the ellipsoid is axis-aligned and represent it by the length of each axis $a$, $b$, and $c$. Given this representation the volume of the ellipsoid is
#
# $$
# V = \frac{4}{3} \pi a b c
# $$
#
# and surface area approximated by
#
# $$
# S \approx 4 \pi \sqrt[p]{\frac{a^pb^p + a^pc^p + b^pc^p}{3}},
# $$
# where $p\approx 1.6075$ yields a relative error of at most 1.061%.
# Full details and other approximations are discussed on [Wikipedia](https://en.wikipedia.org/wiki/Ellipsoid).
#
# ## Projection onto constrained ellipsoid
#
# The nearest ellipsoid (parametrized by $(a, b, c)$), with unit surface area, to the set of points $\{(x_i, y_i, z_i)\}$ can be found in the least-squares sense,
#
# $$
# \begin{array}{ll}
#   \text{minimize (over $a, b, c$)} & \sum_{i=1}^{m} \left(\frac{x_i^2}{a^2} + \frac{y_i^2}{b^2} + \frac{z_i^2}{c^2} - 1\right)^2 \\
#   \text{subject to} & 4 \pi \sqrt[p]{\frac{(ab)^p + (ac)^p + (bc)^p}{3}} = 1
# \end{array}
# $$
#
# which can be written in standard form as
#
# $$
# \begin{array}{ll}
#   \text{minimize} & \|A u - \mathbf{1}_m\|^2 \\
#   \text{subject to} & 4 \pi \sqrt[p]{\frac{1}{3} \left[ \left(\frac{1}{\sqrt{u_1u_2}}\right)^p + \left(\frac{1}{\sqrt{u_1u_3}}\right)^p + \left(\frac{1}{\sqrt{u_2u_3}}\right)^p \right]  } = 1
# \end{array}
# $$
#
# where
#
# $$
# A = \begin{bmatrix}
#   x_1^2 & y_1^2 & z_1^2 \\
#   \vdots & \vdots & \vdots \\
#   x_m^2 & y_m^2 & z_m^2
# \end{bmatrix}
# $$
#
# and $u = \left(\frac{1}{a^2}, \frac{1}{b^2}, \frac{1}{c^2}\right)^\top$.
#
#
# ## Bilevel optimization
#
# Our overall problem can then be stated as
#
# $$
# \begin{array}{ll}
#   \text{minimize (over $\{(x_i, y_i)\}$)} & \sqrt{u_1^\star u_2^\star u_3^\star} \\
#   \text{subject to} & u^\star = \text{argmin} \; \|Au - \mathbf{1}_m\|^2 \\
#   & \hphantom{y =} \text{subject to} \; 4 \pi \sqrt[p]{\frac{1}{3} \left[ \left({\sqrt{u_1}}\right)^p + \left({\sqrt{u_2}}\right)^p + \left({\sqrt{u_3}}\right)^p \right]  } - \sqrt{u_1u_2u_3} = 0
# \end{array}
# $$
#
# where we have stated the lower-level problem in terms of $u$ rather than $(a, b)$, and therefore instead of maximizing $\frac{4}{3} \pi a b c$, we minimize $\sqrt{u_1 u_2 u_2} = \frac{1}{abc}$.

# %%
import math
import numpy as np
import scipy.optimize as opt
import torch
import torch.nn as nn
# %matplotlib ipympl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import warnings
warnings.filterwarnings('ignore')

# ellipse area and circumferencce
def ellipsoid_volume(a, b,c):
    """Returns the volume of an ellipsoid parametrized as (x/a)^2 + (y/b)^2 + (z/c)^2 = 1."""
    return 4/3 * math.pi * a * b * c

def ellipsoid_surface_area(a, b, c, p=1.6075):
    """Returns the approximate surface area of an ellipsoid."""
    a_p = a**p
    b_p = b**p
    c_p = c**p
    return 4 * math.pi * (1/3 * (a_p*b_p + a_p*c_p + b_p*c_p))**(1/p)

# ellipse plotting
def plot_ellipsoid(ax, a, b, c, **kwargs):
    """Plot an ellipse parametrized by (a, b, c)."""
    phi = torch.linspace(0, 2 * math.pi, 100)
    theta = torch.linspace(0, math.pi, 100)
    phi, theta = torch.meshgrid(phi, theta)
    x = a * torch.sin(theta) * torch.cos(phi)
    y = b * torch.sin(theta) * torch.sin(phi)
    z = c * torch.cos(theta)
    ax.plot_wireframe(x, y, z, **kwargs)
    ax.set_aspect('equal', adjustable='box')

# ellipse fitting
def fit_ellipsoid(xs, p):
    """Find ellipsoid parameters u = (1/a^2, 1/b^2, 1/c^2) that best fit the data."""
    n_batches = xs.size(0)
    results = torch.zeros(n_batches, 3, dtype=torch.double)
    for batch_number, x in enumerate(xs):
        data = x.detach().numpy()
        A = data.T ** 2
        b = np.ones(A.shape[0])
        u0 = np.linalg.lstsq(A, b)[0]
        eq_const = {'type': 'eq',
                    'fun' : lambda u: np.array([1]) if (np.any(u < 0.0)) else 
                    np.array([
                        4 * math.pi * (1/3 * (math.sqrt(u[0])**p + math.sqrt(u[1])**p + math.sqrt(u[2])**p))**(1/p) - math.sqrt(u[0] * u[1] * u[2])
                        ])
                    }
        res = opt.minimize(lambda u: np.sum((A @ u - b) ** 2), u0, method='SLSQP', constraints=[eq_const], 
                        options={'ftol': 1e-9, 'disp': False})
        results[batch_number] = torch.tensor(res.x, dtype=torch.double, requires_grad=True)
    return results

# sample a noisy ellipse
sqrt_m = 25
m = sqrt_m * sqrt_m
a, b, c = 0.25, 0.1, 0.4
nu = 1.0e-2
p = 1.6075

print("Ellipsoid (blue) ({:0.3}, {:0.3}, {:0.3}) has volume {:0.3} and surface area {:0.3}.".format(a, b, c, ellipsoid_volume(a, b, c), ellipsoid_surface_area(a, b, c, p)))

phi = 2.0 * math.pi * torch.linspace(0.0, 1.0, sqrt_m)
theta = math.pi * torch.linspace(0.0, 1.0, sqrt_m)
phi, theta = torch.meshgrid(phi, theta)
x = a * torch.sin(theta) * torch.cos(phi)
y = b * torch.sin(theta) * torch.sin(phi)
z = c * torch.cos(theta)
data = torch.stack((x.flatten(),y.flatten(),z.flatten()), dim=0)
data = data + nu * torch.randn(3, m, dtype=torch.double)
data = data.unsqueeze(0)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
kwargs = {
    'color': 'blue',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a, b, c, **kwargs)
ax.scatter(data[0, 0].numpy(), data[0, 1].numpy(), data[0, 2].numpy(), color='b', alpha=0.8, s=1)

u = fit_ellipsoid(data, p).squeeze()
print(u[:3])
a_hat = math.sqrt(1.0 / u[0])
b_hat = math.sqrt(1.0 / u[1])
c_hat = math.sqrt(1.0 / u[2])
kwargs = {
    'color': 'red',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a_hat, b_hat, c_hat, **kwargs)

print("Ellipsoid (red) estimate ({:0.3}, {:0.3}, {:0.3}) has volume {:0.3} and surface area {:0.3}.".format(a_hat, b_hat, c_hat, ellipsoid_volume(a_hat, b_hat, c_hat), ellipsoid_surface_area(a_hat, b_hat, c_hat, p)))
plt.show()
# Out:
# Ellipsoid (blue) (0.25, 0.1, 0.4) has volume 0.0419 and surface area 0.76.
# tensor([  8.8052, 104.0306,   5.9615], dtype=torch.float64,
#        grad_fn=<SliceBackward0>)
# Ellipsoid (red) estimate (0.337, 0.098, 0.41) has volume 0.0567 and surface area 1.0.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Derivatives
#
# Computing gradients by hand is tedious so we'll rely on autograd. Here we make use of the infrastructure provided in `ddn.basic.node` from the DDN respoitory (https://github.com/anucvml/ddn). **Requires `ddn` to be installed.**

# %%
# set correct location for DDN repository code and import basic node functionality
import sys
sys.path.append("../../../ddn/")
from ddn.pytorch.node import *
    
class EllipsoidConstrainedProjectionNode(EqConstDeclarativeNode):
    """A DDN node for the constrained ellipse projection problem. Gradients will be calculated automatically."""

    def __init__(self, m):
        super().__init__(eps=1.0e-4) # relax tolerance on optimality test 
        # make sure node is properly constructed
        self.n = tuple([3 * m]) # number of parameters x number of points
        self.m = m # number of points

    def objective(self, xs, y):
        n_batches = xs.size(0)
        data = xs.view(n_batches, 3, -1)  # reshape to (n_batches, 3, m)
        A = torch.transpose(data, 1, 2).pow(2)  # A has shape [n_batches, m, 3]
        b_tensor = torch.ones(n_batches, A.size(1), 1, device=xs.device, dtype=torch.double)  # [n_batches, m, 1]
        y = y.view(n_batches,3,1)
        return torch.sum((torch.matmul(A, y) - b_tensor).pow(2), dim=(1, 2))
    
    def equality_constraints(self, xs, y):
        # y is of shape [m x number of parameters] (same as u)
        sqrt_y = torch.sqrt(y)
        u1 = sqrt_y[:,0]
        u2 = sqrt_y[:,1]
        u3 = sqrt_y[:,2]
        average = 1/3 * (u1**p + u2**p + u3**p)
        return 4 * math.pi * average**(1/p) - u1*u2*u3
    
    def solve(self, xs):
        # process batches independently
        n_batches = xs.size(0)
        results = torch.zeros(n_batches, 3, dtype=torch.double)
        for batch_number, x in enumerate(xs):
            assert(len(x) == self.n[0])
            data = x.reshape(3, -1).detach().numpy()
            A = data.T ** 2
            b = np.ones(A.shape[0])

            # compute unconstrained solution as an initialization
            u0 = np.linalg.lstsq(A, b)[0]
            
            # now enforce constraints
            eq_const = {'type': 'eq',
                        'fun' : lambda u: np.array([1]) if (np.any(u < 0.0)) else 
                        np.array([
                            4 * math.pi * (1/3 * (math.sqrt(u[0])**p + math.sqrt(u[1])**p + math.sqrt(u[2])**p))**(1/p) - math.sqrt(u[0] * u[1] * u[2])
                            ])
                        }
            res = opt.minimize(lambda u: np.sum((A @ u - b) ** 2), u0, method='SLSQP', constraints=[eq_const], 
                            options={'ftol': 1e-9, 'disp': False})
            if not res.success:
                print("SOLVE failed:", res.message)
                print(res)

            results[batch_number] = torch.tensor(res.x, dtype=torch.double, requires_grad=True)
        return results, None
    
    
class EllipsoidInverseVolumeNode(AbstractNode):
    """DDN node for computing one over the volume of an ellipsoid."""
    def __init__(self):
        super().__init__()
        self.n = m

    def solve(self, xs):
        # xs is the u vector we receive
        return torch.sqrt(xs[:,0] * xs[:,1] * xs[:,2]), None

    def gradient(self, xs, y=None, ctx=None):
        sqrt_xs = torch.sqrt(xs)
        sqrt_u1u2 = sqrt_xs[:,0] * sqrt_xs[:,1]
        sqrt_u1u3 = sqrt_xs[:,0] * sqrt_xs[:,2]
        sqrt_u2u3 = sqrt_xs[:,1] * sqrt_xs[:,2]
        gradients = 1/2 * torch.stack((sqrt_u2u3/sqrt_xs[:,0], 
                                       sqrt_u1u3/sqrt_xs[:,1],
                                       sqrt_u1u2/sqrt_xs[:,2]), dim=1)
        return tuple(gradients)
    

class ComposedNode(AbstractNode):
    """Composes two deep declarative nodes f and g to produce y = g(f(x)). The resulting composition
    behaves exactly like a single deep declarative node, that is, it has the same interface and
    as such can be further composed with other nodes to form a chain."""

    def __init__(self, nodeA, nodeB):
        assert (nodeA.m == nodeB.n)
        super().__init__()
        self.nodeA = nodeA
        self.nodeB = nodeB

    def solve(self, x):
        """Overrides the solve method to first compute z = nodeA.solve(x) and then y = nodeB.solve(z). Returns
        the dual variables from both nodes."""
        z, ctxA = self.nodeA.solve(x)
        y, ctxB = self.nodeB.solve(z)
        return y, {'ctxA': ctxA, 'ctxB': ctxB, 'z': z}

    def gradient(self, x, y=None, ctx=None):
        """Overrides the gradient method to compute the composed gradient by the chain rule."""

        # we need to resolve for z since there is currently no way to store this
        if ctx is None:
            z, _ = self.nodeA.solve(x)
        else:
            z = ctx['z']
        Dz = self.nodeA.jacobian(x, y=z)
        Dz = torch.stack(Dz).squeeze(0)
        # print("Dz.shape, Dz", Dz.shape, Dz, "type", type(Dz), "len", len(Dz))
        Dy = self.nodeB.gradient(z)
        Dy = torch.stack(Dy)
        Dy = Dy.view(Dy.size(0),1,-1)
        # print("Dy.shape, Dy", Dy.shape, Dy, "type", type(Dy), "len", len(Dy))
        # print("result", torch.bmm(Dy, Dz))
        return torch.bmm(Dy, Dz)

# %% [markdown]
# # Optimizing
#
# We now optimize the inital samples in a direction to maximize the area of the projected ellipse using gradient descent.

# %%
from ddn.pytorch.composition import ComposedNode

node = ComposedNode(EllipsoidConstrainedProjectionNode(m), EllipsoidInverseVolumeNode())

n_batches = data.size(0)
x_init = data.view(n_batches, -1)
x_init.requires_grad = True
y_init, _ = node.solve(x_init)

history = [y_init]

x = x_init.clone()
for i in range(50):
    y, _ = node.solve(x)

    history.append(y)

    if True:
        u = fit_ellipsoid(x.view(n_batches, 3, -1), p)
        a_hat = math.sqrt(1.0 / u[:,0])
        b_hat = math.sqrt(1.0 / u[:,1])
        c_hat = math.sqrt(1.0 / u[:,2])
        print("{:5d}: ellipsoid estimate ({:0.3}, {:0.3}, {:0.3}) has volume {:0.3} and surface area {:0.3}.".format(i, a_hat, b_hat, c_hat, ellipsoid_volume(a_hat, b_hat, c_hat), ellipsoid_surface_area(a_hat, b_hat, c_hat, p)))
    ctx = {'z': u}
    dLdx = node.gradient(x, y, ctx=ctx)
    x -= 4.0e-2 * dLdx.flatten()
    
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
kwargs = {
    'color': 'blue',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a, b, c, **kwargs)
ax.scatter(data[0, 0].numpy(), data[0, 1].numpy(), data[0, 2].numpy(), color='b', alpha=0.8, s=1)


final_data = x.reshape(1, 3, -1).detach()
ax.scatter(final_data[0, 0].numpy(), final_data[0, 1].numpy(), final_data[0, 2].numpy(), color='g', marker='+', alpha=0.8, s=1)

u = fit_ellipsoid(final_data, p)
a_hat = math.sqrt(1.0 / u[:,0])
b_hat = math.sqrt(1.0 / u[:,1])
c_hat = math.sqrt(1.0 / u[:,2])
kwargs = {
    'color': 'green',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a_hat, b_hat, c_hat, **kwargs)

print("Final ellipsoid ({:0.3}, {:0.3},{:0.3}) has volume {:0.3} and surface area {:0.3}.".format(a_hat, b_hat, c_hat, ellipsoid_volume(a_hat, b_hat, c_hat), ellipsoid_surface_area(a_hat, b_hat, c_hat, p)))
# plt.axis('square')
plt.legend(['initial true', 'initial samples', 'final samples', 'final projected'])
plt.show()
# Out:
#     0: ellipsoid estimate (0.337, 0.098, 0.41) has volume 0.0567 and surface area 1.0.
#     1: ellipsoid estimate (0.199, 0.321, 0.328) has volume 0.0879 and surface area 1.0.
#     2: ellipsoid estimate (0.209, 0.314, 0.326) has volume 0.0893 and surface area 1.0.
#     3: ellipsoid estimate (0.217, 0.308, 0.323) has volume 0.0903 and surface area 1.0.
#     4: ellipsoid estimate (0.223, 0.303, 0.321) has volume 0.0911 and surface area 1.0.
#     5: ellipsoid estimate (0.229, 0.299, 0.319) has volume 0.0916 and surface area 1.0.
#     6: ellipsoid estimate (0.234, 0.295, 0.318) has volume 0.0921 and surface area 1.0.
#     7: ellipsoid estimate (0.239, 0.292, 0.316) has volume 0.0924 and surface area 1.0.
#     8: ellipsoid estimate (0.243, 0.29, 0.314) has volume 0.0927 and surface area 1.0.
#     9: ellipsoid estimate (0.246, 0.288, 0.313) has volume 0.0929 and surface area 1.0.
#    10: ellipsoid estimate (0.249, 0.286, 0.311) has volume 0.0931 and surface area 1.0.
#    11: ellipsoid estimate (0.252, 0.285, 0.31) has volume 0.0932 and surface area 1.0.
#    12: ellipsoid estimate (0.255, 0.284, 0.309) has volume 0.0933 and surface area 1.0.
#    13: ellipsoid estimate (0.257, 0.283, 0.307) has volume 0.0934 and surface area 1.0.
#    14: ellipsoid estimate (0.259, 0.282, 0.306) has volume 0.0935 and surface area 1.0.
#    15: ellipsoid estimate (0.261, 0.281, 0.305) has volume 0.0936 and surface area 1.0.
#    16: ellipsoid estimate (0.262, 0.28, 0.304) has volume 0.0936 and surface area 1.0.
#    17: ellipsoid estimate (0.264, 0.28, 0.303) has volume 0.0937 and surface area 1.0.
#    18: ellipsoid estimate (0.265, 0.28, 0.302) has volume 0.0937 and surface area 1.0.
#    19: ellipsoid estimate (0.266, 0.279, 0.301) has volume 0.0937 and surface area 1.0.
#    20: ellipsoid estimate (0.267, 0.279, 0.3) has volume 0.0938 and surface area 1.0.
#    21: ellipsoid estimate (0.269, 0.279, 0.299) has volume 0.0938 and surface area 1.0.
#    22: ellipsoid estimate (0.269, 0.279, 0.298) has volume 0.0938 and surface area 1.0.
#    23: ellipsoid estimate (0.27, 0.279, 0.297) has volume 0.0939 and surface area 1.0.
#    24: ellipsoid estimate (0.271, 0.279, 0.297) has volume 0.0939 and surface area 1.0.
#    25: ellipsoid estimate (0.272, 0.279, 0.296) has volume 0.0939 and surface area 1.0.
#    26: ellipsoid estimate (0.273, 0.279, 0.295) has volume 0.0939 and surface area 1.0.
#    27: ellipsoid estimate (0.273, 0.279, 0.295) has volume 0.0939 and surface area 1.0.
#    28: ellipsoid estimate (0.274, 0.279, 0.294) has volume 0.0939 and surface area 1.0.
#    29: ellipsoid estimate (0.274, 0.279, 0.293) has volume 0.0939 and surface area 1.0.
#    30: ellipsoid estimate (0.275, 0.279, 0.293) has volume 0.0939 and surface area 1.0.
#    31: ellipsoid estimate (0.275, 0.279, 0.292) has volume 0.094 and surface area 1.0.
#    32: ellipsoid estimate (0.276, 0.279, 0.292) has volume 0.094 and surface area 1.0.
#    33: ellipsoid estimate (0.276, 0.279, 0.291) has volume 0.094 and surface area 1.0.
#    34: ellipsoid estimate (0.276, 0.279, 0.291) has volume 0.094 and surface area 1.0.
#    35: ellipsoid estimate (0.277, 0.279, 0.29) has volume 0.094 and surface area 1.0.
#    36: ellipsoid estimate (0.277, 0.279, 0.29) has volume 0.094 and surface area 1.0.
#    37: ellipsoid estimate (0.277, 0.279, 0.29) has volume 0.094 and surface area 1.0.
#    38: ellipsoid estimate (0.278, 0.279, 0.289) has volume 0.094 and surface area 1.0.
#    39: ellipsoid estimate (0.278, 0.28, 0.289) has volume 0.094 and surface area 1.0.
#    40: ellipsoid estimate (0.278, 0.28, 0.289) has volume 0.094 and surface area 1.0.
#    41: ellipsoid estimate (0.278, 0.28, 0.288) has volume 0.094 and surface area 1.0.
#    42: ellipsoid estimate (0.279, 0.28, 0.288) has volume 0.094 and surface area 1.0.
#    43: ellipsoid estimate (0.279, 0.28, 0.288) has volume 0.094 and surface area 1.0.
#    44: ellipsoid estimate (0.279, 0.28, 0.287) has volume 0.094 and surface area 1.0.
#    45: ellipsoid estimate (0.279, 0.28, 0.287) has volume 0.094 and surface area 1.0.
#    46: ellipsoid estimate (0.279, 0.28, 0.287) has volume 0.094 and surface area 1.0.
#    47: ellipsoid estimate (0.279, 0.28, 0.287) has volume 0.094 and surface area 1.0.
#    48: ellipsoid estimate (0.28, 0.28, 0.286) has volume 0.094 and surface area 1.0.
#    49: ellipsoid estimate (0.28, 0.28, 0.286) has volume 0.094 and surface area 1.0.
# Final ellipsoid (0.28, 0.281,0.286) has volume 0.094 and surface area 1.0.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
node = EllipsoidConstrainedProjectionNode(m)

class EllipseConstrainedProjectionFunction(DeclarativeFunction):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

class SqrtProductLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, input):
        return torch.sqrt(input[:,0] * input[:,1] * input[:,2])

y_init = EllipseConstrainedProjectionFunction.apply(node, x_init)
sqrt_prod_loss = SqrtProductLoss()
history = [y_init]
x = x_init.clone().detach().requires_grad_(True)
torch_opt = torch.optim.SGD([x], lr=0.05)
# lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=torch_opt,
#                                                           mode='min',
#                                                           factor=0.8,
#                                                           patience=3,
#                                                           threshold=1e-4)

for i in range(60):
    torch_opt.zero_grad(set_to_none=True)
    y = EllipseConstrainedProjectionFunction.apply(node, x)
    history.append(y.detach().clone())
    if True:
        u = fit_ellipsoid(x.view(n_batches, 3, -1), p)
        print("y,u", y,u)
        a_hat = math.sqrt(1.0 / u[:,0])
        b_hat = math.sqrt(1.0 / u[:,1])
        c_hat = math.sqrt(1.0 / u[:,2])
        print("{:5d}: ellipsoid estimate ({:0.3}, {:0.3}, {:0.3}) has volume {:0.7} and surface area {:0.3}.".format(i, a_hat, b_hat, c_hat, ellipsoid_volume(a_hat, b_hat, c_hat), ellipsoid_surface_area(a_hat, b_hat, c_hat, p)))
    loss = sqrt_prod_loss(y)
    loss.backward()
    torch_opt.step()

    # lr_scheduler.step(loss)
    # current_lr = torch_opt.param_groups[0]['lr']
    # print(f"Iteration {i}: Current Learning Rate = {current_lr:.6f}")


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
kwargs = {
    'color': 'blue',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a, b, c, **kwargs)
ax.scatter(data[0, 0].numpy(), data[0, 1].numpy(), data[0, 2].numpy(), color='b', alpha=0.8, s=1)

final_data = x.reshape(1, 3, -1).detach()
ax.scatter(final_data[0, 0].numpy(), final_data[0, 1].numpy(), final_data[0, 2].numpy(), color='g', marker='+', alpha=0.8, s=1)

u = fit_ellipsoid(final_data, p)
a_hat = math.sqrt(1.0 / u[:,0])
b_hat = math.sqrt(1.0 / u[:,1])
c_hat = math.sqrt(1.0 / u[:,2])
kwargs = {
    'color': 'green',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.5
}
plot_ellipsoid(ax, a_hat, b_hat, c_hat, **kwargs)

print("Final ellipsoid ({:0.3}, {:0.3},{:0.3}) has volume {:0.7} and surface area {:0.3}.".format(a_hat, b_hat, c_hat, ellipsoid_volume(a_hat, b_hat, c_hat), ellipsoid_surface_area(a_hat, b_hat, c_hat, p)))
# plt.axis('square')
plt.legend(['initial true', 'initial samples', 'final samples', 'final projected'])
plt.show()
# Out:
# y,u tensor([[  8.8052, 104.0306,   5.9615]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[  8.8052, 104.0306,   5.9615]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#     0: ellipsoid estimate (0.337, 0.098, 0.41) has volume 0.05668382 and surface area 1.0.
# y,u tensor([[27.4172,  8.2894, 10.3700]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[27.4172,  8.2894, 10.3700]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#     1: ellipsoid estimate (0.191, 0.347, 0.311) has volume 0.08628297 and surface area 1.0.
# y,u tensor([[24.4148,  8.7792, 10.5061]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[24.4148,  8.7792, 10.5061]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#     2: ellipsoid estimate (0.202, 0.337, 0.309) has volume 0.08827007 and surface area 1.0.
# y,u tensor([[22.3192,  9.2099, 10.6210]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[22.3192,  9.2099, 10.6210]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#     3: ellipsoid estimate (0.212, 0.33, 0.307) has volume 0.08964789 and surface area 1.0.
# y,u tensor([[20.7588,  9.5939, 10.7224]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[20.7588,  9.5939, 10.7224]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#     4: ellipsoid estimate (0.219, 0.323, 0.305) has volume 0.09064516 and surface area 1.0.
# y,u tensor([[19.5471,  9.9387, 10.8144]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[19.5471,  9.9387, 10.8144]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#     5: ellipsoid estimate (0.226, 0.317, 0.304) has volume 0.09138673 and surface area 1.0.
# y,u tensor([[18.5783, 10.2490, 10.8993]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[18.5783, 10.2490, 10.8993]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#     6: ellipsoid estimate (0.232, 0.312, 0.303) has volume 0.09194836 and surface area 1.0.
# y,u tensor([[17.7870, 10.5286, 10.9788]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[17.7870, 10.5286, 10.9788]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#     7: ellipsoid estimate (0.237, 0.308, 0.302) has volume 0.09237936 and surface area 1.0.
# y,u tensor([[17.1299, 10.7801, 11.0539]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[17.1299, 10.7801, 11.0539]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#     8: ellipsoid estimate (0.242, 0.305, 0.301) has volume 0.0927134 and surface area 1.0.
# y,u tensor([[16.5772, 11.0062, 11.1251]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[16.5772, 11.0062, 11.1251]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#     9: ellipsoid estimate (0.246, 0.301, 0.3) has volume 0.0929743 and surface area 1.0.
# y,u tensor([[16.1077, 11.2088, 11.1930]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[16.1077, 11.2088, 11.1930]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    10: ellipsoid estimate (0.249, 0.299, 0.299) has volume 0.09317938 and surface area 1.0.
# y,u tensor([[15.7053, 11.3900, 11.2579]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[15.7053, 11.3900, 11.2579]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    11: ellipsoid estimate (0.252, 0.296, 0.298) has volume 0.09334143 and surface area 1.0.
# y,u tensor([[15.3582, 11.5517, 11.3200]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[15.3582, 11.5517, 11.3200]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    12: ellipsoid estimate (0.255, 0.294, 0.297) has volume 0.0934701 and surface area 1.0.
# y,u tensor([[15.0569, 11.6955, 11.3796]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[15.0569, 11.6955, 11.3796]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    13: ellipsoid estimate (0.258, 0.292, 0.296) has volume 0.09357271 and surface area 1.0.
# y,u tensor([[14.7941, 11.8230, 11.4367]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[14.7941, 11.8230, 11.4367]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    14: ellipsoid estimate (0.26, 0.291, 0.296) has volume 0.09365487 and surface area 1.0.
# y,u tensor([[14.5639, 11.9357, 11.4915]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[14.5639, 11.9357, 11.4915]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    15: ellipsoid estimate (0.262, 0.289, 0.295) has volume 0.09372092 and surface area 1.0.
# y,u tensor([[14.3616, 12.0352, 11.5440]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[14.3616, 12.0352, 11.5440]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    16: ellipsoid estimate (0.264, 0.288, 0.294) has volume 0.09377423 and surface area 1.0.
# y,u tensor([[14.1830, 12.1226, 11.5943]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[14.1830, 12.1226, 11.5943]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    17: ellipsoid estimate (0.266, 0.287, 0.294) has volume 0.09381744 and surface area 1.0.
# y,u tensor([[14.0251, 12.1992, 11.6426]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[14.0251, 12.1992, 11.6426]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    18: ellipsoid estimate (0.267, 0.286, 0.293) has volume 0.0938526 and surface area 1.0.
# y,u tensor([[13.8849, 12.2661, 11.6887]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.8849, 12.2661, 11.6887]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    19: ellipsoid estimate (0.268, 0.286, 0.292) has volume 0.09388132 and surface area 1.0.
# y,u tensor([[13.7603, 12.3245, 11.7329]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.7603, 12.3245, 11.7329]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    20: ellipsoid estimate (0.27, 0.285, 0.292) has volume 0.0939049 and surface area 1.0.
# y,u tensor([[13.6492, 12.3751, 11.7751]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.6492, 12.3751, 11.7751]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    21: ellipsoid estimate (0.271, 0.284, 0.291) has volume 0.09392432 and surface area 1.0.
# y,u tensor([[13.5500, 12.4189, 11.8155]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.5500, 12.4189, 11.8155]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    22: ellipsoid estimate (0.272, 0.284, 0.291) has volume 0.0939404 and surface area 1.0.
# y,u tensor([[13.4612, 12.4567, 11.8540]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.4612, 12.4567, 11.8540]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    23: ellipsoid estimate (0.273, 0.283, 0.29) has volume 0.09395377 and surface area 1.0.
# y,u tensor([[13.3816, 12.4891, 11.8907]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.3816, 12.4891, 11.8907]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    24: ellipsoid estimate (0.273, 0.283, 0.29) has volume 0.09396493 and surface area 1.0.
# y,u tensor([[13.3100, 12.5168, 11.9258]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.3100, 12.5168, 11.9258]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    25: ellipsoid estimate (0.274, 0.283, 0.29) has volume 0.09397429 and surface area 1.0.
# y,u tensor([[13.2457, 12.5404, 11.9591]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.2457, 12.5404, 11.9591]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    26: ellipsoid estimate (0.275, 0.282, 0.289) has volume 0.09398217 and surface area 1.0.
# y,u tensor([[13.1877, 12.5603, 11.9909]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.1877, 12.5603, 11.9909]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    27: ellipsoid estimate (0.275, 0.282, 0.289) has volume 0.09398884 and surface area 1.0.
# y,u tensor([[13.1354, 12.5771, 12.0212]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.1354, 12.5771, 12.0212]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    28: ellipsoid estimate (0.276, 0.282, 0.288) has volume 0.0939945 and surface area 1.0.
# y,u tensor([[13.0881, 12.5911, 12.0500]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.0881, 12.5911, 12.0500]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    29: ellipsoid estimate (0.276, 0.282, 0.288) has volume 0.09399932 and surface area 1.0.
# y,u tensor([[13.0453, 12.6027, 12.0774]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.0453, 12.6027, 12.0774]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    30: ellipsoid estimate (0.277, 0.282, 0.288) has volume 0.09400345 and surface area 1.0.
# y,u tensor([[13.0065, 12.6121, 12.1034]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[13.0065, 12.6121, 12.1034]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    31: ellipsoid estimate (0.277, 0.282, 0.287) has volume 0.094007 and surface area 1.0.
# y,u tensor([[12.9713, 12.6198, 12.1281]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.9713, 12.6198, 12.1281]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    32: ellipsoid estimate (0.278, 0.281, 0.287) has volume 0.09401006 and surface area 1.0.
# y,u tensor([[12.9394, 12.6258, 12.1516]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.9394, 12.6258, 12.1516]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    33: ellipsoid estimate (0.278, 0.281, 0.287) has volume 0.0940127 and surface area 1.0.
# y,u tensor([[12.9102, 12.6305, 12.1738]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.9102, 12.6305, 12.1738]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    34: ellipsoid estimate (0.278, 0.281, 0.287) has volume 0.09401499 and surface area 1.0.
# y,u tensor([[12.8837, 12.6341, 12.1950]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.8837, 12.6341, 12.1950]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    35: ellipsoid estimate (0.279, 0.281, 0.286) has volume 0.09401698 and surface area 1.0.
# y,u tensor([[12.8595, 12.6366, 12.2150]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.8595, 12.6366, 12.2150]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    36: ellipsoid estimate (0.279, 0.281, 0.286) has volume 0.09401871 and surface area 1.0.
# y,u tensor([[12.8374, 12.6383, 12.2340]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.8374, 12.6383, 12.2340]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    37: ellipsoid estimate (0.279, 0.281, 0.286) has volume 0.09402023 and surface area 1.0.
# y,u tensor([[12.8172, 12.6392, 12.2521]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.8172, 12.6392, 12.2521]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    38: ellipsoid estimate (0.279, 0.281, 0.286) has volume 0.09402155 and surface area 1.0.
# y,u tensor([[12.7987, 12.6395, 12.2691]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.7987, 12.6395, 12.2691]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    39: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402271 and surface area 1.0.
# y,u tensor([[12.7818, 12.6393, 12.2853]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.7818, 12.6393, 12.2853]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    40: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402374 and surface area 1.0.
# y,u tensor([[12.7662, 12.6387, 12.3007]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.7662, 12.6387, 12.3007]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    41: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402463 and surface area 1.0.
# y,u tensor([[12.7519, 12.6377, 12.3152]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.7519, 12.6377, 12.3152]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    42: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402543 and surface area 1.0.
# y,u tensor([[12.7388, 12.6365, 12.3289]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.7388, 12.6365, 12.3289]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    43: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402612 and surface area 1.0.
# y,u tensor([[12.7267, 12.6350, 12.3419]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.7267, 12.6350, 12.3419]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    44: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402674 and surface area 1.0.
# y,u tensor([[12.7156, 12.6333, 12.3543]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.7156, 12.6333, 12.3543]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    45: ellipsoid estimate (0.28, 0.281, 0.285) has volume 0.09402728 and surface area 1.0.
# y,u tensor([[12.7053, 12.6314, 12.3659]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.7053, 12.6314, 12.3659]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    46: ellipsoid estimate (0.281, 0.281, 0.284) has volume 0.09402777 and surface area 1.0.
# y,u tensor([[12.6959, 12.6295, 12.3769]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6959, 12.6295, 12.3769]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    47: ellipsoid estimate (0.281, 0.281, 0.284) has volume 0.09402819 and surface area 1.0.
# y,u tensor([[12.6871, 12.6274, 12.3874]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6871, 12.6274, 12.3874]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    48: ellipsoid estimate (0.281, 0.281, 0.284) has volume 0.09402857 and surface area 1.0.
# y,u tensor([[12.6790, 12.6254, 12.3973]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6790, 12.6254, 12.3973]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    49: ellipsoid estimate (0.281, 0.281, 0.284) has volume 0.09402891 and surface area 1.0.
# y,u tensor([[12.6715, 12.6232, 12.4066]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6715, 12.6232, 12.4066]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    50: ellipsoid estimate (0.281, 0.281, 0.284) has volume 0.09402921 and surface area 1.0.
# y,u tensor([[12.6646, 12.6211, 12.4154]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6646, 12.6211, 12.4154]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    51: ellipsoid estimate (0.281, 0.281, 0.284) has volume 0.09402947 and surface area 1.0.
# y,u tensor([[12.6581, 12.6190, 12.4238]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6581, 12.6190, 12.4238]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    52: ellipsoid estimate (0.281, 0.282, 0.284) has volume 0.0940297 and surface area 1.0.
# y,u tensor([[12.6522, 12.6168, 12.4317]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6522, 12.6168, 12.4317]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    53: ellipsoid estimate (0.281, 0.282, 0.284) has volume 0.09402991 and surface area 1.0.
# y,u tensor([[12.6466, 12.6147, 12.4391]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6466, 12.6147, 12.4391]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    54: ellipsoid estimate (0.281, 0.282, 0.284) has volume 0.0940301 and surface area 1.0.
# y,u tensor([[12.6415, 12.6127, 12.4462]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6415, 12.6127, 12.4462]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    55: ellipsoid estimate (0.281, 0.282, 0.283) has volume 0.09403026 and surface area 1.0.
# y,u tensor([[12.6367, 12.6107, 12.4529]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6367, 12.6107, 12.4529]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    56: ellipsoid estimate (0.281, 0.282, 0.283) has volume 0.09403041 and surface area 1.0.
# y,u tensor([[12.6322, 12.6087, 12.4592]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6322, 12.6087, 12.4592]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    57: ellipsoid estimate (0.281, 0.282, 0.283) has volume 0.09403054 and surface area 1.0.
# y,u tensor([[12.6281, 12.6068, 12.4651]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6281, 12.6068, 12.4651]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    58: ellipsoid estimate (0.281, 0.282, 0.283) has volume 0.09403066 and surface area 1.0.
# y,u tensor([[12.6242, 12.6049, 12.4707]], dtype=torch.float64,
#        grad_fn=<EllipseConstrainedProjectionFunctionBackward>) tensor([[12.6242, 12.6049, 12.4707]], dtype=torch.float64,
#        grad_fn=<CopySlices>)
#    59: ellipsoid estimate (0.281, 0.282, 0.283) has volume 0.09403076 and surface area 1.0.
# Final ellipsoid (0.281, 0.282,0.283) has volume 0.09403085 and surface area 1.0.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
r = math.sqrt(1/(4*math.pi))
condition = (final_data[0, 0]**2 + final_data[0, 1]**2 + final_data[0, 2]**2) < (r**2)

# Reshape the condition to match the tensor shape for indexing
mask = condition.unsqueeze(0).expand_as(final_data)

# Use the mask to index the tensor
filtered_data = final_data[mask].view(final_data.size(0), final_data.size(1), -1)

print(f"There are {len(filtered_data[0][0])} points inside the ellipsoid.")

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
kwargs = {
    'color': 'blue',   # Color of the wireframe
    'linestyle': '-',  # Line style (solid)
    'linewidth': 0.5,  # Line width
    'alpha': 0.1
}
plot_ellipsoid(ax, a_hat, b_hat, c_hat, **kwargs)
ax.scatter(filtered_data[0, 0].numpy(), filtered_data[0, 1].numpy(), filtered_data[0, 2].numpy(), color='g', marker='+', alpha=0.8, s=1)
plt.show()
# Out:
# There are 33 points inside the ellipsoid.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
